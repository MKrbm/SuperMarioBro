# %%
def helloworld():
    return "hello world!"
import numpy as np

# %%
class area:
    def __init__(self,x):
        self.x = x
    
    def area(self):
        return np.pi**2*self.x

# %%
<<<<<<< local
A = area(10)
=======
A = area(3)
>>>>>>> remote
A.area()
# Out:
# <<<<<<< local
# 98.69604401089359
# ...
# 29.608813203268074
# >>>>>>> remote
